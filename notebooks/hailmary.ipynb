# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_absolute_error
import math
import seaborn as sns
import xgboost as xgb

# %%
train = pd.read_csv('../data/01_raw/dengue_features_train.csv')
test = pd.read_csv('../data/01_raw/dengue_features_test.csv')
labels = pd.read_csv('../data/01_raw/dengue_labels_train.csv')
sub_format = pd.read_csv('../data/01_raw/submission_format.csv')

# %%
train['source'] = 'train'
test['source'] = 'test'
df = pd.concat([train, test])

# %%
df.fillna(method='ffill')
# Out:
# /var/folders/1x/y3znw75x2292b78hj_x2yv240000gn/T/ipykernel_38855/1193302488.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#     city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0     sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1     sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2     sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3     sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4     sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
# ..   ...   ...         ...             ...       ...       ...       ...
# 411   iq  2013          22      2013-05-28  0.301471  0.380029  0.280629
# 412   iq  2013          23      2013-06-04  0.247600  0.296343  0.285371
# 413   iq  2013          24      2013-06-11  0.238729  0.251029  0.252586
# 414   iq  2013          25      2013-06-18  0.310429  0.302700  0.406614
# 415   iq  2013          26      2013-06-25  0.339467  0.240071  0.356943
#
#       ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0    0.177617                 12.42             297.572857  ...
# 1    0.155486                 22.82             298.211429  ...
# 2    0.170843                 34.54             298.781429  ...
# 3    0.235886                 15.36             298.987143  ...
# 4    0.247340                  7.52             299.518571  ...
# ..        ...                   ...                    ...  ...
# 411  0.383186                 41.12             297.774286  ...
# 412  0.350357                 71.52             297.167143  ...
# 413  0.249771                 78.96             295.831429  ...
# 414  0.403943                 39.54             295.778571  ...
# 415  0.273600                 51.80             297.372857  ...
#
#      reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# 0                               73.365714                         12.42
# 1                               77.368571                         22.82
# 2                               82.052857                         34.54
# 3                               80.337143                         15.36
# 4                               80.460000                          7.52
# ..                                    ...                           ...
# 411                             89.990000                         41.12
# 412                             93.891429                         71.52
# 413                             94.967143                         78.96
# 414                             89.057143                         39.54
# 415                             87.030000                         51.80
#
#      reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# 0                                14.012857           2.628571
# 1                                15.372857           2.371429
# 2                                16.848571           2.300000
# 3                                16.672857           2.428571
# 4                                17.210000           3.014286
# ..                                     ...                ...
# 411                              17.185714          10.100000
# 412                              17.448571           9.657143
# 413                              16.410000           7.385714
# 414                              15.137143           8.228571
# 415                              16.148571          11.542857
#
#      station_avg_temp_c  station_diur_temp_rng_c  station_max_temp_c  \
# 0             25.442857                 6.900000                29.4
# 1             26.714286                 6.371429                31.7
# 2             26.714286                 6.485714                32.2
# 3             27.471429                 6.771429                33.3
# 4             28.942857                 9.371429                35.0
# ..                  ...                      ...                 ...
# 411           27.400000                 9.050000                32.6
# 412           27.520000                10.720000                33.8
# 413           27.200000                10.075000                32.6
# 414           26.700000                 8.480000                32.2
# 415           27.350000                 9.675000                32.6
#
#      station_min_temp_c  station_precip_mm  source
# 0                  20.0               16.0   train
# 1                  22.2                8.6   train
# 2                  22.8               41.4   train
# 3                  23.3                4.0   train
# 4                  23.9                5.8   train
# ..                  ...                ...     ...
# 411                21.8               33.0    test
# 412                21.4               68.0    test
# 413                21.6               93.2    test
# 414                21.8               34.1    test
# 415                22.0               14.9    test
#
# [1872 rows x 25 columns]

# %%
df['sj'] = df['city'].apply(lambda x: 1 if x == 'sj' else 0)
df['iq'] = df['city'].apply(lambda x: 1 if x == 'iq' else 0)
df = df.drop(['city','week_start_date'], axis=1)
df.head()
# Out:
#    year  weekofyear   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# 0  1990          18  0.122600  0.103725  0.198483  0.177617
# 1  1990          19  0.169900  0.142175  0.162357  0.155486
# 2  1990          20  0.032250  0.172967  0.157200  0.170843
# 3  1990          21  0.128633  0.245067  0.227557  0.235886
# 4  1990          22  0.196200  0.262200  0.251200  0.247340
#
#    precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# 0                 12.42             297.572857             297.742857
# 1                 22.82             298.211429             298.442857
# 2                 34.54             298.781429             298.878571
# 3                 15.36             298.987143             299.228571
# 4                  7.52             299.518571             299.664286
#
#    reanalysis_dew_point_temp_k  ...  reanalysis_specific_humidity_g_per_kg  \
# 0                   292.414286  ...                              14.012857
# 1                   293.951429  ...                              15.372857
# 2                   295.434286  ...                              16.848571
# 3                   295.310000  ...                              16.672857
# 4                   295.821429  ...                              17.210000
#
#    reanalysis_tdtr_k  station_avg_temp_c  station_diur_temp_rng_c  \
# 0           2.628571           25.442857                 6.900000
# 1           2.371429           26.714286                 6.371429
# 2           2.300000           26.714286                 6.485714
# 3           2.428571           27.471429                 6.771429
# 4           3.014286           28.942857                 9.371429
#
#    station_max_temp_c  station_min_temp_c  station_precip_mm  source  sj  iq
# 0                29.4                20.0               16.0   train   1   0
# 1                31.7                22.2                8.6   train   1   0
# 2                32.2                22.8               41.4   train   1   0
# 3                33.3                23.3                4.0   train   1   0
# 4                35.0                23.9                5.8   train   1   0
#
# [5 rows x 25 columns]

# %%
df['week_sin'] = np.sin(2 * np.pi * df['weekofyear']/53)
df['week_cos'] = np.cos(2 * np.pi * df['weekofyear']/53)

# %%
df.columns
# Out:
# Index(['year', 'weekofyear', 'ndvi_ne', 'ndvi_nw', 'ndvi_se', 'ndvi_sw',
#        'precipitation_amt_mm', 'reanalysis_air_temp_k',
#        'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k',
#        'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k',
#        'reanalysis_precip_amt_kg_per_m2',
#        'reanalysis_relative_humidity_percent', 'reanalysis_sat_precip_amt_mm',
#        'reanalysis_specific_humidity_g_per_kg', 'reanalysis_tdtr_k',
#        'station_avg_temp_c', 'station_diur_temp_rng_c', 'station_max_temp_c',
#        'station_min_temp_c', 'station_precip_mm', 'source', 'sj', 'iq',
#        'week_sin', 'week_cos'],
#       dtype='object')

# %%
rolling_cols = [
    "reanalysis_sat_precip_amt_mm",
    "reanalysis_min_air_temp_k",
    "station_min_temp_c",
    "reanalysis_air_temp_k",
    "reanalysis_avg_temp_k",
    "reanalysis_dew_point_temp_k",
    "reanalysis_specific_humidity_g_per_kg",
    "station_avg_temp_c",
]

for col in rolling_cols:
    df[col + '_rolling_2'] = df[col].rolling(window=2).mean()


for col in rolling_cols:
    df[col + '_rolling_4'] = df[col].rolling(window=4).mean()


for col in rolling_cols:
    df[col + '_rolling_6'] = df[col].rolling(window=6).mean()

# %% [markdown]
# ## Model building

# %%
df_model_building = df.copy()

# %%
df_train = df_model_building.query("source == 'train'").drop(['source'], axis=1)
df_test = df_model_building.query("source == 'test'").drop(['source'], axis=1)

# %%
df_test.columns
# Out:
# Index(['year', 'weekofyear', 'ndvi_ne', 'ndvi_nw', 'ndvi_se', 'ndvi_sw',
#        'precipitation_amt_mm', 'reanalysis_air_temp_k',
#        'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k',
#        'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k',
#        'reanalysis_precip_amt_kg_per_m2',
#        'reanalysis_relative_humidity_percent', 'reanalysis_sat_precip_amt_mm',
#        'reanalysis_specific_humidity_g_per_kg', 'reanalysis_tdtr_k',
#        'station_avg_temp_c', 'station_diur_temp_rng_c', 'station_max_temp_c',
#        'station_min_temp_c', 'station_precip_mm', 'sj', 'iq', 'week_sin',
#        'week_cos', 'reanalysis_precip_amt_kg_per_m2_rolling_2',
#        'reanalysis_sat_precip_amt_mm_rolling_2',
#        'reanalysis_min_air_temp_k_rolling_2', 'station_min_temp_c_rolling_2',
#        'reanalysis_air_temp_k_rolling_2', 'reanalysis_avg_temp_k_rolling_2',
#        'reanalysis_dew_point_temp_k_rolling_2',
#        'reanalysis_specific_humidity_g_per_kg_rolling_2',
#        'station_avg_temp_c_rolling_2',
#        'reanalysis_precip_amt_kg_per_m2_rolling_4',
#        'reanalysis_sat_precip_amt_mm_rolling_4',
#        'reanalysis_min_air_temp_k_rolling_4', 'station_min_temp_c_rolling_4',
#        'reanalysis_air_temp_k_rolling_4', 'reanalysis_avg_temp_k_rolling_4',
#        'reanalysis_dew_point_temp_k_rolling_4',
#        'reanalysis_specific_humidity_g_per_kg_rolling_4',
#        'station_avg_temp_c_rolling_4',
#        'reanalysis_precip_amt_kg_per_m2_rolling_3',
#        'reanalysis_sat_precip_amt_mm_rolling_3',
#        'reanalysis_min_air_temp_k_rolling_3', 'station_min_temp_c_rolling_3',
#        'reanalysis_air_temp_k_rolling_3', 'reanalysis_avg_temp_k_rolling_3',
#        'reanalysis_dew_point_temp_k_rolling_3',
#        'reanalysis_specific_humidity_g_per_kg_rolling_3',
#        'station_avg_temp_c_rolling_3'],
#       dtype='object')

# %%
X = df_train.copy().drop(['weekofyear'],axis=1)
y = labels['total_cases']

# %%
split_index = math.floor(X.shape[0] * 0.8)

X_train = X.loc[:split_index, ]
X_val = X.loc[split_index:, ]
y_train = y.loc[:split_index, ]
y_val = y.loc[split_index:,]

# %%
rf = RandomForestRegressor(n_estimators=200, max_depth=7)
rf.fit(X_train, y_train)
y_hat = rf.predict(X_val)
mae = mean_absolute_error(y_val, y_hat)
print(f"Mean absolute error is {mae}")
# Out:
# Mean absolute error is 7.455127719305617

# %%
xg_reg = xgb.XGBRegressor(objective='reg:squarederror', seed=42)
xg_reg.fit(X_train, y_train)
y_hat = xg_reg.predict(X_val)
mae = mean_absolute_error(y_val, y_hat)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 7.977948919142762

# %%
df_test.columns
# Out:
# Index(['year', 'weekofyear', 'ndvi_ne', 'ndvi_nw', 'ndvi_se', 'ndvi_sw',
#        'precipitation_amt_mm', 'reanalysis_air_temp_k',
#        'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k',
#        'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k',
#        'reanalysis_precip_amt_kg_per_m2',
#        'reanalysis_relative_humidity_percent', 'reanalysis_sat_precip_amt_mm',
#        'reanalysis_specific_humidity_g_per_kg', 'reanalysis_tdtr_k',
#        'station_avg_temp_c', 'station_diur_temp_rng_c', 'station_max_temp_c',
#        'station_min_temp_c', 'station_precip_mm', 'sj', 'iq', 'week_sin',
#        'week_cos', 'reanalysis_precip_amt_kg_per_m2_rolling_2',
#        'reanalysis_sat_precip_amt_mm_rolling_2',
#        'reanalysis_min_air_temp_k_rolling_2', 'station_min_temp_c_rolling_2',
#        'reanalysis_air_temp_k_rolling_2', 'reanalysis_avg_temp_k_rolling_2',
#        'reanalysis_dew_point_temp_k_rolling_2',
#        'reanalysis_specific_humidity_g_per_kg_rolling_2',
#        'station_avg_temp_c_rolling_2',
#        'reanalysis_precip_amt_kg_per_m2_rolling_4',
#        'reanalysis_sat_precip_amt_mm_rolling_4',
#        'reanalysis_min_air_temp_k_rolling_4', 'station_min_temp_c_rolling_4',
#        'reanalysis_air_temp_k_rolling_4', 'reanalysis_avg_temp_k_rolling_4',
#        'reanalysis_dew_point_temp_k_rolling_4',
#        'reanalysis_specific_humidity_g_per_kg_rolling_4',
#        'station_avg_temp_c_rolling_4',
#        'reanalysis_precip_amt_kg_per_m2_rolling_3',
#        'reanalysis_sat_precip_amt_mm_rolling_3',
#        'reanalysis_min_air_temp_k_rolling_3', 'station_min_temp_c_rolling_3',
#        'reanalysis_air_temp_k_rolling_3', 'reanalysis_avg_temp_k_rolling_3',
#        'reanalysis_dew_point_temp_k_rolling_3',
#        'reanalysis_specific_humidity_g_per_kg_rolling_3',
#        'station_avg_temp_c_rolling_3'],
#       dtype='object')

# %%
df_test = df_test.copy().drop(['weekofyear'],axis=1)
df_test['predictions'] = rf.predict(df_test)
df_test['total_cases'] = df_test['predictions'].apply(lambda x: int(round(x)))

submissions = pd.concat([sub_format.drop(['total_cases'], axis=1),df_test['total_cases']],axis=1)
submissions.to_csv('../data/07_model_output/RS_mean_2_4_6_test_concat.csv',sep=',',index=False)

submissions2 = pd.merge(sub_format.drop(['total_cases'],axis=1),df_test['total_cases'], how='left', left_index=True, right_index=True)
submissions2.to_csv('../data/07_model_output/RS_mean_2_4_6_test_merge.csv',sep=',',index=False)

# %%
# df_test = df_test.copy().drop(['weekofyear'],axis=1)
# df_test['predictions'] = rf.predict(df_test)
# df_test['total_cases'] = df_test['predictions'].apply(lambda x: int(round(x)))

# submissions = pd.merge(sub_format.drop(['total_cases'],axis=1),df_test['total_cases'], how='left', left_index=True, right_index=True)
# submissions.to_csv('output/test.csv',sep=',',index=False)

# %%
df_test.total_cases.plot()
# Out:
# <Axes: >

# %%
submissions.total_cases.plot()
# Out:
# <Axes: >

# %%
pd.concat([df_train, labels['total_cases']], axis=1).corr()['total_cases'].sort_values(ascending=False)
# Out:
# total_cases                                        1.000000
# reanalysis_min_air_temp_k_rolling_4                0.351470
# station_min_temp_c_rolling_4                       0.345545
# reanalysis_min_air_temp_k_rolling_3                0.345272
# reanalysis_min_air_temp_k_rolling_2                0.337498
# reanalysis_min_air_temp_k                          0.325252
# station_min_temp_c_rolling_3                       0.325010
# reanalysis_air_temp_k_rolling_4                    0.314495
# station_min_temp_c_rolling_2                       0.301732
# reanalysis_air_temp_k_rolling_3                    0.300095
# sj                                                 0.292624
# reanalysis_air_temp_k_rolling_2                    0.285120
# station_min_temp_c                                 0.267109
# reanalysis_air_temp_k                              0.264952
# weekofyear                                         0.216452
# reanalysis_avg_temp_k_rolling_4                    0.206310
# reanalysis_dew_point_temp_k_rolling_4              0.192026
# reanalysis_avg_temp_k_rolling_3                    0.189527
# station_avg_temp_c_rolling_4                       0.181048
# reanalysis_dew_point_temp_k_rolling_3              0.177535
# reanalysis_specific_humidity_g_per_kg_rolling_4    0.176364
# reanalysis_avg_temp_k_rolling_2                    0.172643
# reanalysis_specific_humidity_g_per_kg_rolling_3    0.162632
# reanalysis_dew_point_temp_k_rolling_2              0.161080
# station_avg_temp_c_rolling_3                       0.159412
# reanalysis_avg_temp_k                              0.151637
# reanalysis_specific_humidity_g_per_kg_rolling_2    0.147065
# reanalysis_dew_point_temp_k                        0.142531
# station_avg_temp_c_rolling_2                       0.138123
# reanalysis_specific_humidity_g_per_kg              0.129861
# station_avg_temp_c                                 0.116109
# week_cos                                           0.110494
# reanalysis_precip_amt_kg_per_m2_rolling_4         -0.000258
# reanalysis_precip_amt_kg_per_m2_rolling_3         -0.001702
# reanalysis_precip_amt_kg_per_m2_rolling_2         -0.007546
# reanalysis_precip_amt_kg_per_m2                   -0.010031
# reanalysis_sat_precip_amt_mm_rolling_4            -0.037909
# precipitation_amt_mm                              -0.038740
# reanalysis_sat_precip_amt_mm                      -0.038740
# reanalysis_sat_precip_amt_mm_rolling_3            -0.039183
# station_max_temp_c                                -0.039219
# reanalysis_sat_precip_amt_mm_rolling_2            -0.042079
# station_precip_mm                                 -0.074374
# reanalysis_relative_humidity_percent              -0.132452
# ndvi_se                                           -0.168612
# reanalysis_max_air_temp_k                         -0.191345
# ndvi_sw                                           -0.196461
# ndvi_nw                                           -0.202235
# station_diur_temp_rng_c                           -0.237844
# ndvi_ne                                           -0.241376
# reanalysis_tdtr_k                                 -0.278483
# week_sin                                          -0.282807
# iq                                                -0.292624
# year                                              -0.306806
# Name: total_cases, dtype: float64

# %%
df.head(2)
# Out:
#    year  weekofyear  ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# 0  1990          18   0.1226  0.103725  0.198483  0.177617
# 1  1990          19   0.1699  0.142175  0.162357  0.155486
#
#    precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# 0                 12.42             297.572857             297.742857
# 1                 22.82             298.211429             298.442857
#
#    reanalysis_dew_point_temp_k  ...  station_avg_temp_c_rolling_4  \
# 0                   292.414286  ...                           NaN
# 1                   293.951429  ...                           NaN
#
#    reanalysis_precip_amt_kg_per_m2_rolling_3  \
# 0                                        NaN
# 1                                        NaN
#
#    reanalysis_sat_precip_amt_mm_rolling_3  \
# 0                                     NaN
# 1                                     NaN
#
#    reanalysis_min_air_temp_k_rolling_3  station_min_temp_c_rolling_3  \
# 0                                  NaN                           NaN
# 1                                  NaN                           NaN
#
#    reanalysis_air_temp_k_rolling_3  reanalysis_avg_temp_k_rolling_3  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
#
#    reanalysis_dew_point_temp_k_rolling_3  \
# 0                                    NaN
# 1                                    NaN
#
#    reanalysis_specific_humidity_g_per_kg_rolling_3  \
# 0                                              NaN
# 1                                              NaN
#
#    station_avg_temp_c_rolling_3
# 0                           NaN
# 1                           NaN
#
# [2 rows x 54 columns]

# %%
columns_to_encode = ['city']

for col in columns_to_encode:
    unique_values = df[col].unique()
    for unique_value in unique_values:
        df[unique_value] = df[col].apply(lambda x: 1 if x == unique_value else 0)

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/Work/git_repo/miniComp/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'city'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 4
#       1 columns_to_encode = ['city']
#       3 for col in columns_to_encode:
# ----> 4     unique_values = df[col].unique()
#       5     for unique_value in unique_values:
#       6         df[unique_value] = df[col].apply(lambda x: 1 if x == unique_value else 0)
#
# File ~/Documents/Work/git_repo/miniComp/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/Documents/Work/git_repo/miniComp/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'city'
